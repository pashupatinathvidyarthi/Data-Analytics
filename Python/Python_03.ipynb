# %%
a=3

# %%
a
# Out:
# 3

# %%
b="Pashupati"

# %%
b
# Out:
# 'Pashupati'

# %%
b[2]
# Out:
# 's'

# %%
b[-1]
# Out:
# 'i'

# %%
#another type of data character
list_container=[1,2,3,"Pashupati",3+5J,True,"a"]

# %%
type(list_container)
# Out:
# list

# %%
list_container[4]
# Out:
# (3+5j)

# %%
list_container[4]=5+36j

# %%
list_container
# Out:
# [1, 2, 3, 'Pashupati', (5+36j), True, 'a']

# %%
#Objects/container whose stae or value can be changed are called mutable objects/container. 
# List is mutable.

# %%
b
# Out:
# 'Pashupati'

# %%
b[2]
# Out:
# 's'

# %%
b[2]='i'  #Error occurs here
#Strings are immutable
