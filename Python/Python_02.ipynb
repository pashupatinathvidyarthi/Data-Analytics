# %%
print("Hello World")
# Out:
# Hello World

# %%
a = 3

# %%
a
# Out:
# 3

# %% [markdown]
# Variables are placeholder where we will keep variety of data which we can use to write logic

# %%
type(a)
# Out:
# int

# %%
b=4.2

# %%
b
# Out:
# 4.2

# %%
type(b)
# Out:
# float

# %%
d=True

# %%
type(d)
# Out:
# bool

# %%
True-False
# Out:
# 1

# %%
True*False
# Out:
# 0

# %% [markdown]
# True/False (It will through error)

# %%
False/True
# Out:
# 0.0

# %% [markdown]
# Complex Number

# %%
c = 5+6j #complex number = real+imaginary

# %%
type(c)
# Out:
# complex

# %%
c.real
# Out:
# 5.0

# %%
c.imag
# Out:
# 6.0

# %% [markdown]
# Rules of defining Variable
# A variable starts with a letter or underscore character.

# %%
_location = "Delhi"

# %%
Data_Analytics = "Pashupati"

# %%
Data_Analytics
# Out:
# 'Pashupati'

# %% [markdown]
# Multi-line Comments

# %%
"""
This is a multi-line Comment.
"""
# Out:
# '\nThis is a multi-line Comment.\n'

# %% [markdown]
# Single Line Comments

# %%
#This is a single line comment

# %%
help("keywords")
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not

# %% [markdown]
# Standard Input and Output in Python

# %%
name=input("Enter your name : ")

# %%
print(name)
# Out:
# Pashupati

# %%
type(name)
# Out:
# str

# %% [markdown]
# Type Casting

# %%
s="123"

# %%
type(s)
# Out:
# str

# %%
int(s)
# Out:
# 123

# %%
bool(0)
# Out:
# False

# %%
bool(1)
# Out:
# True

# %%
a="Pass"
int(a) #Through an error!

# %% [markdown]
# Python is Case-Sensitive.
