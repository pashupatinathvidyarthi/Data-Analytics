# %% [markdown]
# Operators

# %%
"""
1.Arithmetic Operators
    +  Addition
    -  Subtraction
    *  Multiplication
    /  Division
    // Floor Division
    %  Modulus
    ** Exponentiation
2.Comparison Operators
    == Equal to
    != Not equal to
    >  Greater than
    <  Less than
    >= Greater than or equal to
    <= Less than or equal to
3.Logical Operators
    and Logical AND
    or  Logical OR
    not Logical NOT
4.Assignment Operators
    =   Assignment
    +=  Add and assign
    -=  Subtract and assign
    *=  Multiply and assign
    /=  Divide and assign
    //= Floor divide and assign
    %=  Modulus and assign
    **= Exponentiate and assign
5.Bitwise Operators
    &  Bitwise AND
    |  Bitwise OR
    ^  Bitwise XOR
    ~  Bitwise NOT
    << Left shift
    >> Right shift      
6.Membership Operators
    in      Membership test (returns True if found)
    not in  Membership test (returns True if not found)
7.Identity Operators
    is      Identity test (returns True if both refer to the same object)
    is not  Identity test (returns True if both refer to different objects)
"""

# %%
#What is operators>>> special keywords to perform operations on variables and values
#why? To manipulate data and perform calculations
"""
    Arithmetic Operators
        +  Addition
        -  Subtraction
        *  Multiplication
        /  Division
        // Floor Division
        %  Modulus
        ** Exponentiation
"""
a=5
b=2
a+b
# Out:
# 7

# %%
5+2
# Out:
# 7

# %%
add=5+2
print(add)
# Out:
# 7

# %%
20-3
# Out:
# 17

# %%
3*4
# Out:
# 12

# %%
20 / 4
# Out:
# 5.0

# %%
#modulus operator>>> returns the remainder of a division operation
10 % 3  #remainder is 1 because 3*3=9 and 10-9=1 
15 % 4  #remainder is 3 because 4*3=12 and 15-12=3
# Out:
# 3

# %%
2 ** 3 #2 raised to the power of 3=8
9 ** 0.5 #square root of 9=3.0
# Out:
# 3.0

# %%
4 // 3  #floor division returns the largest integer less than or equal to the division result
# Out:
# 1

# %%
#Comparison Operators>> compare two values and return a boolean value (True or False)
2 == 2  #Equal to
# Out:
# True

# %%
2 != 2  #Not equal to
# Out:
# False

# %%
2!= 3  #Not equal to
# Out:
# True

# %%
10>2
# Out:
# True

# %% [markdown]
# #All comparison operators return boolean values (True or False)

# %%
10>=10
# Out:
# True

# %%
10<1
# Out:
# False

# %%
#Logical Operators
#and Logical AND
True and True #returns True if both operands are True
# Out:
# True

# %%
True and False  #returns False if any operand is False
# Out:
# False

# %%
#Not Logical NOT
not True  #returns False
not False #returns True

# %%
#Assignment Operators
a=10 #Assignment

# %%
a
# Out:
# 10

# %%
a+5
# Out:
# 15

# %%
a=10

# %%
a=a+10

# %%
a
# Out:
# 20

# %%
a+=5  #Add and assign

# %%
a
# Out:
# 25

# %%
a*=2  #Multiply and assign

# %%
a
# Out:
# 50

# %%
a/=3  #Divide and assign

# %%
a
# Out:
# 16.666666666666668

# %%
#Membership Operators
#in      Membership test (returns True if found)    
name="Pashupati"
'P' in name
# Out:
# True

# %%
fruits = ["apple", "banana", "cherry"]
"banana" in fruits  #returns True because "banana" is in the list
# Out:
# True

# %%
name="Pashupati"
'p' in name.lower()  #case insensitive check
# Out:
# True

# %%
name="Pashupati"
'P' in name.upper()  #case insensitive check
# Out:
# True

# %%
"DATA" not in "DATABASE"  #returns False because "DATA" is found in "DATABASE"
# Out:
# False

# %%
"Pass" not in "Pashupati"  #returns True because "Pass" is not found in "Pashupati"
# Out:
# True

# %%
a=["data", "analytics", "python"]

# %%
"c" not in a  #returns True because "c" is not found in the list
# Out:
# True

# %%
#Identity Operators >>> Compare the memory locations of two objects
a=2

# %%
b=3

# %%
#Identity Operators
#is      Identity test (returns True if both refer to the same object)  
a is b
# Out:
# False

# %%
a="Pashupati"
b=a
b is a  #returns True because both refer to the same object
# Out:
# True

# %%
a=2
b=3
a is b #returns False because both refer to different objects
# Out:
# False

# %%
a=2
b=3
a is not b  #returns True because both refer to different objects
# Out:
# True

# %%
#Bitwise Operators >>> Perform bit-level operations on integers
10 & 10
# Out:
# 10

# %%
18 & 3
# Out:
# 2

# %%
bin(10)  #binary representation of 10 is 1010
# Out:
# '0b1010'

# %%
bin(2) # binary representation of 2 is 10
# Out:
# '0b10'

# %%
bin(18)  #binary representation of 18 is 10010
# Out:
# '0b10010'

# %%
3 | 5  #Bitwise OR operation between 3(0011) and 5(0101) results in 7(0111)
# Out:
# 7

# %%
#negation of a number
~5  #Bitwise NOT operation results in -6
# Out:
# -6

# %%
~1
# Out:
# -2

# %%
~7
# Out:
# -8

# %%
#Bitwise XOR >>> returns 1 when exactly one of the bits is 1
4 ^ 5  #Bitwise XOR operation between 4(0100) and 5(0101) results in 1(0001)
# Out:
# 1

# %%
bin(4)
# Out:
# '0b100'

# %%
bin(5)
# Out:
# '0b101'

# %%
5^3
# Out:
# 6

# %%
bin(5)
# Out:
# '0b101'

# %%
bin(3)
# Out:
# '0b11'

# %%
#Shift >>> Left shift and Right shift

# %%
#left shift put number of zeros to the right
2 << 1  #Left shift operation shifts bits to the left by 1 position
# Out:
# 4

# %%
bin(2)
# Out:
# '0b10'

# %%
bin(1)
# Out:
# '0b1'

# %%
5<<1
# Out:
# 10

# %%
bin(5)
# Out:
# '0b101'

# %%
bin(1)
# Out:
# '0b1'

# %%
#Right shift removes number of bits from the right
5 >> 1  #Right shift operation shifts bits to the right by 1 position
# Out:
# 2

# %%
bin(5)
# Out:
# '0b101'

# %%
bin(1)
# Out:
# '0b1'

# %%
#Order of precedence of operators
#1.Parentheses (),[],{}
#2.Exponentiation **
#3.Unary plus and minus +x, -x
#4.Multiplication, Division, Floor Division, Modulus *, /, //, %
#5.Addition and Subtraction +, -
#6.Bitwise Shift <<, >>
