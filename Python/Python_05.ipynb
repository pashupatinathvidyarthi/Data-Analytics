# %%
#Type conversion is the process of changing the data type of a value to another data type.
a="5"
type(a)  #str
# Out:
# str

# %%
type(2)
# Out:
# int

# %%
#Type Casting is of two types: Implicit and Explicit

# %%
x=2

# %%
type(x)
# Out:
# int

# %%
2+3.4
# Out:
# 5.4

# %%
type(3.4)
# Out:
# float

# %%
"pashupati"+"nath"
# Out:
# 'pashupatinath'

# %%
x="5"

# %%
x+"pashupati"
# Out:
# '5pashupati'

# %%
#Explicit Type Casting >>> Converting data from one type to another by user intervention

#string
#int
#float
#bool

# %%
x=22.5
y=int(x)

# %%
type(y)
# Out:
# int

# %%
y
# Out:
# 22

# %%
s="33"
a=int(s)

# %%
type(a)
# Out:
# int

# %%
b="33.5"
c=float(b)

# %%
c
# Out:
# 33.5

# %%
type(c)
# Out:
# float

# %%
bool(0)
# Out:
# False

# %%
bool(1)
# Out:
# True
