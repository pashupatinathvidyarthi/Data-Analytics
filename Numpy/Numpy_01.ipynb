# %% [markdown]
# ![Process](Process.png)

# %% [markdown]
# Numpy means Numerical Python

# %%
#numpy >>> numerical python
#2005 by Travis Oliphant
#library for numerical computations in python

# %%
pip install numpy
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# ...
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.3 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.3 MB 989.2 kB/s eta 0:00:12
#    -- ------------------------------------- 0.8/12.3 MB 987.4 kB/s eta 0:00:12
#    -- ------------------------------------- 0.8/12.3 MB 987.4 kB/s eta 0:00:12
#    --- ------------------------------------ 1.0/12.3 MB 986.7 kB/s eta 0:00:12
#    ---- ----------------------------------- 1.3/12.3 MB 1.0 MB/s eta 0:00:11
#    ----- ---------------------------------- 1.6/12.3 MB 932.2 kB/s eta 0:00:12
#    ----- ---------------------------------- 1.6/12.3 MB 932.2 kB/s eta 0:00:12
#    ----- ---------------------------------- 1.6/12.3 MB 932.2 kB/s eta 0:00:12
# ...

# %%
import numpy as np

# %%
np.__version__
# Out:
# '2.4.1'

# %%
print(np.__doc__)
# Out:
# NumPy
# =====
#
# Provides
#   1. An array object of arbitrary homogeneous items
#   2. Fast mathematical operations over arrays
#   3. Linear Algebra, Fourier Transforms, Random Number Generation
#
# How to use the documentation
# ----------------------------
# Documentation is available in two forms: docstrings provided
# with the code, and a loose standing reference guide, available from
# `the NumPy homepage <https://numpy.org>`_.
#
# We recommend exploring the docstrings using
# `IPython <https://ipython.org>`_, an advanced Python shell with
# TAB-completion and introspection capabilities.  See below for further
# instructions.
#
# The docstring examples assume that `numpy` has been imported as ``np``::
#
#   >>> import numpy as np
#
# Code snippets are indicated by three greater-than signs::
#
#   >>> x = 42
#   >>> x = x + 1
#
# Use the built-in ``help`` function to view a function's docstring::
#
#   >>> help(np.sort)
#   ... # doctest: +SKIP
#
# ...

# %%
list1=[1,2,3,4,"Pashupati"]

# %%
type(list1)
# Out:
# list

# %%
#Numpy stores the data in an array
#An array is a container used to store the data of same type

# %%
#Why Numpy?
#Computation is Fast >> due to array >> contiguous memory allocation
#mathematical computations

# %%
l=[1,2,3,4,5]

# %%
import numpy as np
array=np.array(l)

# %%
array
# Out:
# array([1, 2, 3, 4, 5])

# %%
l=[1,2,3,4,5.1]
array=np.array(l)

# %%
array
# Out:
# array([1. , 2. , 3. , 4. , 5.1])

# %%
l=[1,2,3,4,5.1,"Pashupati"]
array=np.array(l)

# %%
array
# Out:
# array(['1', '2', '3', '4', '5.1', 'Pashupati'], dtype='<U32')

# %%
#array stores homogeneous data

# %%
type(array)
# Out:
# numpy.ndarray

# %%
array.ndim
# Out:
# 1

# %%
array1=np.array([[1,2,3],[4,5,6]]) #2D array

# %%
array1
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
#number of square brackets = number of dimensions

# %%
array1.ndim
# Out:
# 2

# %%
mat=np.matrix([1,2,3,4,5]) #matrix is a specialized array of 2 dimension always

# %%
type(mat)
# Out:
# numpy.matrix

# %%
np.matrix([[[1,2],[3,4],[5,6],[7,8]]]) #through an error
#matrix cannot be more than 2D

# %%
#more way to construct array
li=[1,2,3]
np.asarray(li)
# Out:
# array([1, 2, 3])

# %%
mat
