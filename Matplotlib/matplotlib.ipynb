# %%
#why do we need visualization?
#Summarize the importance of visualization in data analysis and communication.Visualization is crucial in data analysis and communication because it allows us to represent complex data in a more understandable

#Matplotlib, seaborn, plotly, and bokeh are popular Python libraries for data visualization. Each library has its own strengths and weaknesses, and the choice of which one to use depends on the specific needs of the project. Matplotlib is a widely used library for creating static, animated, and interactive visualizations in Python. It provides a wide range of plotting functions and is highly customizable. Seaborn is built on top of Matplotlib and provides a higher-level interface for creating attractive and informative statistical graphics. Plotly is a library for creating interactive visualizations that can be easily shared online. Bokeh is another library for creating interactive visualizations that can be embedded in web applications. Each of these libraries has its own unique features and capabilities, making them suitable for different types of data visualization tasks.

# %%
#Matplotlib
#Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python. It provides a wide range of plotting functions and is highly customizable. Matplotlib allows you to create various types of plots, such as line plots, scatter plots, bar plots, histograms, and more. It also supports advanced features like subplots, multiple axes, and custom styling. Matplotlib is widely used in the data science community for its flexibility and extensive functionality.

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#bar,line, scatter, histogram, boxplot, pie chart, heatmap, pairplot, violin plot, swarm plot, kde plot

# %%
x=np.random.rand(50)
y=np.random.rand(50)

# %%
x
# Out:
# array([0.76828632, 0.78688869, 0.04898008, 0.73726075, 0.97697375,
#        0.72496562, 0.83300309, 0.60542091, 0.18524681, 0.04345447,
#        0.70413033, 0.67300082, 0.86123137, 0.02817522, 0.29905808,
#        0.55882993, 0.99110089, 0.0930924 , 0.71211991, 0.59944049,
#        0.03571186, 0.04793557, 0.8766103 , 0.20830583, 0.24646265,
#        0.43093721, 0.83798963, 0.86949277, 0.27744245, 0.6882947 ,
#        0.97941051, 0.91890614, 0.88010976, 0.03638544, 0.52252336,
#        0.09587372, 0.52233016, 0.55883759, 0.51642532, 0.03370601,
#        0.98974896, 0.58139263, 0.77944944, 0.85982253, 0.27254602,
#        0.40831694, 0.25209201, 0.03603413, 0.01342668, 0.34931887])

# %%
y
# Out:
# array([0.92120922, 0.4286247 , 0.41681087, 0.01769738, 0.04766904,
#        0.14183188, 0.42106265, 0.19612266, 0.49861921, 0.01003455,
#        0.99452312, 0.14099969, 0.66713288, 0.92343387, 0.66502096,
#        0.18369241, 0.67509831, 0.07287538, 0.83970369, 0.71962136,
#        0.78697248, 0.52230957, 0.95580838, 0.23580125, 0.73186295,
#        0.59433059, 0.3312415 , 0.20899886, 0.43103226, 0.69563062,
#        0.7298149 , 0.22646918, 0.6401555 , 0.73287556, 0.79305683,
#        0.06966097, 0.96274835, 0.11739296, 0.2487317 , 0.86031855,
#        0.48093644, 0.1339118 , 0.42856594, 0.86951925, 0.34846661,
#        0.87519365, 0.45427508, 0.97493495, 0.48696333, 0.02407441])

# %%
#Scatter Plot
plt.scatter(x,y) #To understand relationship between two variables

# %%
np.random.rand(1000)
# Out:
# array([9.54768369e-01, 4.20748182e-01, 3.06326363e-01, 2.82543595e-01,
#        4.63772555e-01, 1.35656762e-01, 1.55437271e-02, 9.12566700e-01,
#        2.48208759e-01, 6.64964755e-02, 5.23555186e-02, 3.85414700e-01,
#        7.76246563e-01, 3.42583804e-01, 4.82205367e-01, 7.18194015e-01,
#        4.93956873e-01, 4.14601393e-01, 3.93423877e-01, 3.77272665e-01,
#        8.41684291e-02, 3.07497194e-01, 6.35609744e-01, 2.17564706e-01,
#        3.07080406e-01, 1.37885139e-01, 4.78416159e-01, 7.59792549e-01,
#        9.34884389e-01, 6.10091211e-01, 7.74332689e-01, 5.06467413e-01,
#        3.84638974e-01, 6.67475653e-01, 5.57539923e-01, 4.28693260e-01,
#        5.38293322e-01, 3.26263876e-01, 8.20027830e-01, 5.15142764e-01,
#        5.97504227e-01, 9.08295769e-02, 3.42649647e-01, 6.70800499e-01,
#        9.39524466e-01, 8.53616423e-01, 9.07154114e-01, 1.87044955e-01,
#        4.24004694e-01, 5.74901932e-01, 6.99536935e-01, 7.59194550e-01,
# ...

# %%
df=pd.DataFrame(np.random.rand(1000), columns=['data'],index=pd.date_range('2024-03-29', periods=1000))

# %%
df
# Out:
#                 data
# 2024-03-29  0.328344
# 2024-03-30  0.784551
# 2024-03-31  0.072746
# 2024-04-01  0.705939
# 2024-04-02  0.210766
# ...              ...
# 2026-12-19  0.529850
# 2026-12-20  0.993549
# 2026-12-21  0.958098
# 2026-12-22  0.317398
# 2026-12-23  0.820719
#
# [1000 rows x 1 columns]

# %%
#Line Chart
#When to use line chart ?
#Line charts are used to visualize trends over time or continuous data. They are particularly effective for showing how a variable changes over a period of time, making it easier to identify patterns, trends, and fluctuations in the data. Line charts are commonly used in time series analysis, financial data visualization, and any situation where you want to track changes in a variable across a continuous range.


df.plot(figsize=(20,8)) #To visualize the data over time, we can use a line plot. The x-axis represents the date, and the y-axis represents the values in the 'data' column. The figsize parameter is used to set the size of the plot.
#20 by 8 inches, which provides a larger area for the plot and makes it easier to see the details. The plot will show how the values in the 'data' column change over time, allowing us to identify any trends or patterns in the data.
# Out:
# <Axes: >

# %%
#Line Plot
#Whenever time components is involved on x-axis, we can use line plot to visualize the data. Line plots are particularly effective for showing trends and patterns in data over time, making it easier to identify changes and fluctuations in the data. They are commonly used in time series analysis, financial data visualization, and any situation where you want to track changes in a variable across a continuous range.
#Depict the relation between two variables in trends, patterns, and fluctuations in the data. Line plots are commonly used in time series analysis, financial data visualization, and any situation where you want to track changes in a variable across a continuous range.

# %%
x=[1,2,3,4,5]
y=[5,1,7,8,2]
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.title('Line Plot to understand the syntax')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# %%
plt.plot(x,y, color='red') #To change the color of the line in the plot, we can use the color parameter in the plt.plot() function. By setting color='red', we specify that we want the line to be red. You can choose from a variety of colors such as 'blue', 'green', 'yellow', etc., or you can use hexadecimal color codes for more specific colors.
plt.title('Line Plot to understand the syntax')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# %%
plt.plot(x,y, color='red',marker='o') #To change the color of the line in the plot, we can use the color parameter in the plt.plot() function. By setting color='red', we specify that we want the line to be red. You can choose from a variety of colors such as 'blue', 'green', 'yellow', etc., or you can use hexadecimal color codes for more specific colors. The marker parameter is used to specify the style of the markers that will be used to represent the data points on the plot. By setting marker='o', we specify that we want circular markers for each data point.
plt.title('Line Plot to understand the syntax')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# %%
plt.plot(x,y, color='red',marker='o', linestyle='--')   #To change the color of the line in the plot, we can use the color parameter in the plt.plot() function. By setting color='red', we specify that we want the line to be red. You can choose from a variety of colors such as 'blue', 'green', 'yellow', etc., or you can use hexadecimal color codes for more specific colors. The marker parameter is used to specify the style of the markers that will be used to represent the data points on the plot. By setting marker='o', we specify that we want circular markers for each data point. The linestyle parameter is used to specify the style of the line connecting the data points. By setting linestyle='dashed', we specify that we want a dashed line.
plt.title('Line Plot to understand the syntax')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# %%
plt.plot(x,y, color='red',marker='o', linestyle='--', linewidth=2)   #To change the color of the line in the plot, we can use the color parameter in the plt.plot() function. By setting color='red', we specify that we want the line to be red. You can choose from a variety of colors such as 'blue', 'green', 'yellow', etc., or you can use hexadecimal color codes for more specific colors. The marker parameter is used to specify the style of the markers that will be used to represent the data points on the plot. By setting marker='o', we specify that we want circular markers for each data point. The linestyle parameter is used to specify the style of the line connecting the data points. By setting linestyle='dashed', we specify that we want a dashed line. The linewidth parameter is used to set the width of the line. By setting linewidth=2, we specify that we want the line to be 2 points wide, which makes it thicker and more visible on the plot.
plt.title('Line Plot to understand the syntax')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# %%
plt.plot(x,y, color='red',marker='o', linestyle='--', linewidth=2, markersize=7)   #To change the color of the line in the plot, we can use the color parameter in the plt.plot() function. By setting color='red', we specify that we want the line to be red. You can choose from a variety of colors such as 'blue', 'green', 'yellow', etc., or you can use hexadecimal color codes for more specific colors. The marker parameter is used to specify the style of the markers that will be used to represent the data points on the plot. By setting marker='o', we specify that we want circular markers for each data point. The linestyle parameter is used to specify the style of the line connecting the data points. By setting linestyle='dashed', we specify that we want a dashed line. The linewidth parameter is used to set the width of the line. By setting linewidth=2, we specify that we want the line to be 2 points wide, which makes it thicker and more visible on the plot. The markersize parameter is used to set the size of the markers. By setting markersize=10, we specify that we want the markers to be larger, making them more prominent on the plot.   
plt.title('Line Plot to understand the syntax')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# %%
plt.plot(x,y, color='red',marker='o', linestyle='--', linewidth=2, markersize=7)   #To change the color of the line in the plot, we can use the color parameter in the plt.plot() function. By setting color='red', we specify that we want the line to be red. You can choose from a variety of colors such as 'blue', 'green', 'yellow', etc., or you can use hexadecimal color codes for more specific colors. The marker parameter is used to specify the style of the markers that will be used to represent the data points on the plot. By setting marker='o', we specify that we want circular markers for each data point. The linestyle parameter is used to specify the style of the line connecting the data points. By setting linestyle='dashed', we specify that we want a dashed line. The linewidth parameter is used to set the width of the line. By setting linewidth=2, we specify that we want the line to be 2 points wide, which makes it thicker and more visible on the plot. The markersize parameter is used to set the size of the markers. By setting markersize=10, we specify that we want the markers to be larger, making them more prominent on the plot.   
plt.title('Line Plot to understand the syntax')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.grid('True') #To add a grid to the plot, we can use the plt.grid() function. By setting grid=True, we specify that we want to display the grid on the plot. The grid helps to improve the readability of the plot by providing reference lines that make it easier to see the values of the data points and understand their positions relative to each other.
plt.show()

# %%
x=[1,2,3,4,5]
y1=[5,1,7,8,2]
y2=[7,8,3,5,1]


plt.plot(x,y1, color='red',marker='o', linestyle='--', linewidth=2, markersize=7,label='y1')
plt.plot(x,y2, color='blue',marker='s', linestyle='--', linewidth=2, markersize=7,label='y2')

plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Line Plot with Multiple Lines')
plt.legend() #To add a legend to the plot, we can use the plt.legend() function. The legend will display the labels for each line, which we specified using the label parameter in the plt.plot() function. This helps to differentiate between the different lines on the plot and provides clarity on what each line represents.
plt.grid('True')
plt.show()

# %%
x=np.linspace(0,10,100) #To create an array of 100 evenly spaced values between 0 and 10, we can use the np.linspace() function from the NumPy library. The first argument (0) is the starting value, the second argument (10) is the ending value, and the third argument (100) specifies the number of values to generate. This will create an array of 100 values that are evenly spaced between 0 and 10, which can be used for plotting or other calculations.

# %%
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
plt.plot(x,np.sin(x))
plt.plot(x,np.cos(x))

# %%
plt.plot(x,np.sin(x),linestyle='--')
plt.show()

# %%
plt.plot(x,np.sin(x),linestyle='-.')
plt.show()

# %%
plt.plot(x,np.sin(x),linestyle=':')

# %%
#plt.figure()  we take 1 blank page
plt.figure()
plt.subplot(1,2,1) #1 row, 2 columns, 1st plot
plt.plot(x,np.sin(x)) #To create a subplot, we can use the plt.subplot() function. The first argument (1) specifies the number of rows in the subplot, the second argument (2) specifies the number of columns, and the third argument (1) specifies that we want to plot on the first subplot. In this case, we are creating a 1x2 grid of subplots and plotting the sine function on the first subplot.

plt.subplot(1,2,2) #1 row, 2 columns, 2nd plot
plt.plot(x,np.cos(x)) #To create a subplot, we can use the plt.subplot() function. The first argument (1) specifies the number of rows in the subplot, the second argument (2) specifies the number of columns, and the third argument (2) specifies that we want to plot on the second subplot. In this case, we are creating a 1x2 grid of subplots and plotting the cosine function on the second subplot.
plt.show()

# %%
plt.figure()
plt.subplot(2,2,1)
plt.plot(x,np.sin(x))
plt.legend('s)')

plt.subplot(2,2,2)
plt.plot(x,np.cos(x))
plt.legend('c')

plt.subplot(2,2,3)
plt.plot(x,np.tan(x))
plt.legend('t')

plt.subplot(2,2,4)
plt.plot(x,np.cos(x+1))
plt.legend('c+1')

plt.show()

# %%
plt.figure()
plt.subplot(2,1,1)
plt.plot(x,np.sin(x))

plt.subplot(2,1,2)
plt.plot(x,np.cos(x))

plt.show()
