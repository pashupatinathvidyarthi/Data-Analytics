# %%
pip install plotly
# Out:
# ...
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.9 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.9 MB 1.3 MB/s eta 0:00:08
#    --- ------------------------------------ 0.8/9.9 MB 1.0 MB/s eta 0:00:09
#    --- ------------------------------------ 0.8/9.9 MB 1.0 MB/s eta 0:00:09
#    ---- ----------------------------------- 1.0/9.9 MB 931.8 kB/s eta 0:00:10
#    ----- ---------------------------------- 1.3/9.9 MB 907.1 kB/s eta 0:00:10
#    ----- ---------------------------------- 1.3/9.9 MB 907.1 kB/s eta 0:00:10
#    ------ --------------------------------- 1.6/9.9 MB 912.1 kB/s eta 0:00:10
#    ------- -------------------------------- 1.8/9.9 MB 940.7 kB/s eta 0:00:09
#    -------- ------------------------------- 2.1/9.9 MB 970.4 kB/s eta 0:00:09
# ...

# %%
import plotly.graph_objects as go
import plotly.express as px
